# %%
### Narges Saeidy
'''#########################################################################'''
import os
import sys
import  time
import random
import numpy as np
from tqdm import tqdm
import nibabel as nib
from PIL import Image
import tensorflow as tf
from skimage.io import imread
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
plt.style.use("ggplot")
from skimage.transform import resize
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.preprocessing.image import  img_to_array
from tensorflow.keras.models import Model
from tensorflow.keras.layers import  BatchNormalization, Activation, Dropout
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.metrics import Recall, Precision
from TV_UNET import get_unet, TV_bin_loss

# %%
'''#########################################################################'''
path=''
im_width=128
im_height=128
num_class=2

'''#########################################################################'''
########## Load dataset 1
train1=nib.load(path+'CT_seg1/tr_im.nii.gz')

train_np1 = np.array(train1.get_fdata())

[x,y,z]=train_np1.shape

train=np.full((z,x,y),0)

for i in range(z):
  train[i,:,:]=train_np1[:,:,i]

mask1 = nib.load(path+'CT_seg1/tr_mask.nii.gz')

mask_np1 = np.array(mask1.get_fdata())

[x,y,z]=mask_np1.shape

mask=np.full((z,x,y),0)

for i in range(z):
  mask[i,:,:]=mask_np1[:,:,i]
  
########## Load dataset 2
ids1 = next(os.walk(path+'CT_seg2/rp_im/'))[2] # list of Masks

print("No. of test image = ", len(ids1))

sys.stdout.flush()

id_train=ids1[0:6]
id_test=ids1[6:]

for n, id_ in tqdm(enumerate(id_train), total=len(id_train)): 
  train2=nib.load(path+'CT_seg2/rp_im/'+id_)
  train_np2 = np.array(train2.get_fdata())
  mask2 = nib.load(path+'CT_seg2/rp_msk/'+id_)
  mask_np2 = np.array(mask2.get_fdata())

  [x,y,z]=train_np2.shape
  train_np2 = resize(train_np2, (512, 512, z), mode = 'constant', preserve_range = True)
  mask_np2= resize(mask_np2, (512, 512, z), mode = 'constant', preserve_range = True)

  X_train=np.full((z,512,512),0)
  X_mask=np.full((z,512,512),0)
  
  for i in range(z):
    X_train[i,:,:]=train_np2[:,:,i]
    X_mask[i,:,:]=mask_np2[:,:,i]

  train=np.vstack((train,X_train))
  mask=np.vstack((mask,X_mask))
  
'''#########################################################################'''
########## Resize data and Label
labels=np.full((len(mask),128,128,num_class),0)

X=np.full((len(train),128,128,1),0)

for i in range(len(mask)):
  X[i,:,:,0]= resize(train[i,:,:], (128, 128), mode = 'constant', preserve_range = True, anti_aliasing=True)
  m1= resize(mask[i,:,:], (128, 128), mode = 'constant', preserve_range = True,anti_aliasing=False)
  
  for ix in range(0,num_class):
    labels[i,:,:,ix] = np.where(m1==ix,1,0)
    
'''#########################################################################'''
########## Imshow normal and COVID-19 images
fig, ax = plt.subplots(1,2, figsize=(10,10))
ax[0].imshow(X[128, ..., 0], cmap='gray')
ax[0].set_title('Normal Image',fontweight="bold", size=20)


ax[1].imshow(X[171, ..., 0], cmap='gray')
ax[1].set_title('COVID-19 Image',fontweight="bold", size=20)

plt.rcParams["axes.grid"] = False
plt.subplots_adjust(wspace=0.1, hspace=-0.65)

######################
i=0
fig, ax = plt.subplots(3,2, figsize=(20, 20))
for j in [3,171]:
    m1= resize(labels[j,:,:,1], (128, 128), mode = 'constant', preserve_range = True,anti_aliasing=False)

    ax[0,i].imshow(X[j, ..., 0], cmap='gray')
    ax[1,i].imshow(X[j, ..., 0], cmap='gray')
    ax[1,i].contour(m1.squeeze(), colors='r', levels=[0.5])
    ax[2,i].imshow(m1, cmap='gray')

    plt.rcParams["axes.grid"] = False
    plt.subplots_adjust(wspace=-0.5, hspace=0.1)

'''#########################################################################'''
########## Applying TV_UNET Model
def dice_coef(y_pred, y_true):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 0.0001) / (K.sum(y_true_f) + K.sum(y_pred_f) + 0.0001)


def dice_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

'''#########################################################################'''
input_img = Input((im_height, im_width,1), name='img')

model = get_unet(input_img, n_filters=64, dropout=0.2, batchnorm=True)


def my_loss(y_true, y_pred):
  layer_names=[layer.name for layer in model.layers]
  for l in layer_names:
    if l==layer_names[-1]:
      value = TV_bin_loss(y_true, y_pred)
    else:
      value = binary_crossentropy(K.flatten(y_true),K.flatten(y_pred))
  return value
  

model.compile(optimizer=Adam(), loss = [my_loss], metrics=['accuracy',dice_loss,Recall(name='recall_1'),
                                                            Precision(name='pre_1')])
model.summary()

'''#########################################################################'''
# Split train and validation
X_train, X_valid, y_train, y_valid = train_test_split(X, labels, test_size=0.1, random_state=42)

callbacks = [
    EarlyStopping(patience=30, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-TV-UNet2.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

results = model.fit(X_train, y_train, batch_size=32, epochs=50, callbacks=callbacks,\
                    validation_data=(X_valid, y_valid))

model.save_weights("model-TV-UNet2.h5")
    
'''#########################################################################'''
########## Plot loss function
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

'''#########################################################################'''
'''#########################################################################'''
'''test'''
# ids1 = next(os.walk(path+'CT_seg2/rp_im_test/'))[2] # list of Masks

sys.stdout.flush()

test=np.full((1,128,128,1),0)

mask_test=np.full((1,128,128),0)

for n, id_ in tqdm(enumerate(id_test), total=len(id_test)): 
  test2=nib.load(path+'CT_seg2/rp_im/'+id_)
  test_np2 = np.array(test2.get_fdata())
  mask_test2 = nib.load(path+'CT_seg2/rp_msk/'+id_)
  mask_test_np2 = np.array(mask_test2.get_fdata())

  [x,y,z]=test_np2.shape
  test_np2 = resize(test_np2, (im_height, im_height, z), mode = 'constant', preserve_range = True)
  mask_np2= resize(mask_test_np2, (im_height, im_height, z), mode = 'constant', preserve_range = True,
                   anti_aliasing=False)

  X_test=np.full((z,im_height,im_height,1),0)
  y_test=np.full((z,im_height,im_height),0)
  
  for i in range(z):
    X_test[i,:,:,0]=test_np2[:,:,i]
    y_test[i,:,:]=mask_np2[:,:,i]

  test=np.vstack((test,X_test))
  mask_test=np.vstack((mask_test,y_test))
  
'''#########################################################################'''
import numpy as np
label_test=np.full((len(mask_test),128,128,num_class),0)

for i in range(len(mask_test)):
  m1=mask_test[i,:,:]
  
  for ix in range(0,num_class):
    label_test[i,:,:,ix] = np.where(m1==ix,1,0)
    
'''#########################################################################'''
########## Load the best Models and plot results
#model.load_weights('weight-UNet.h5')
loaded_model = get_unet(input_img, n_filters=64, dropout=0.2, batchnorm=True)
model.load_weights("model-TV-UNet2.h5")
preds_test1 = model.predict(test, verbose=1)
preds_test_t1 = (preds_test1 > 0.1).astype(np.uint8)

#model.load_weights('weight-TV-UNet.h5')
preds_test2 = model.predict(test, verbose=1)
preds_test_t2 = (preds_test2 > 0.3).astype(np.uint8)

def plot_sample(X, y, binary_preds1, binary_preds2):
    fig, axs = plt.subplots(5, 4, figsize=(50,50),sharex='all')
    i=0
    for ix in [20,50,60,110,120]:
      l=1

      axs[i,0].imshow(X[ix, ..., 0], cmap='gray')
      axs[0,0].set_title('Original CT Images',fontweight="bold", size=40)

      axs[i,1].imshow(y[ix,:,:,l].squeeze(),cmap='gray')
      axs[0,1].set_title('Ground-Truth Mask',fontweight="bold", size=40)

      axs[i,2].imshow(binary_preds1[ix,:,:,l].squeeze(),cmap='gray', vmin=0, vmax=1)
      axs[0,2].set_title('Predicted Mask \n with BCE loss',fontweight="bold", size=40)
      
      axs[i,3].imshow(binary_preds2[ix,:,:,l].squeeze(),cmap='gray', vmin=0, vmax=1)
      axs[0,3].set_title('Predicted Masks \n with BCE+TV Loss',fontweight="bold", size=40);
      
      i+=1
      
      plt.rcParams["axes.grid"] = False
      # plt.subplots_adjust(wspace=-0.5, hspace=0.1)
    plt.savefig("true_pred.png")

plot_sample(test, label_test, preds_test_t1, preds_test_t2)
plt.rcParams["axes.grid"] = False
'''#########################################################################'''
# Out:
# No. of test image =  9
# 100%|██████████| 6/6 [00:18<00:00,  3.08s/it]
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  img (InputLayer)               [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d_38 (Conv2D)             (None, 128, 128, 64  640         ['img[0][0]']
#                                 )
#
#  batch_normalization_36 (BatchN  (None, 128, 128, 64  256        ['conv2d_38[0][0]']
#  ormalization)                  )
#
#  activation_36 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_36[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 128, 128, 64  36928       ['activation_36[0][0]']
#                                 )
#
#  batch_normalization_37 (BatchN  (None, 128, 128, 64  256        ['conv2d_39[0][0]']
#  ormalization)                  )
#
#  activation_37 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_37[0][0]']
#                                 )
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 64, 64, 64)  0           ['activation_37[0][0]']
#
#  dropout_16 (Dropout)           (None, 64, 64, 64)   0           ['max_pooling2d_8[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 64, 64, 128)  73856       ['dropout_16[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 64, 64, 128)  512        ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_38[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 64, 64, 128)  512        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_39[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 32, 32, 128)  0          ['activation_39[0][0]']
#
#  dropout_17 (Dropout)           (None, 32, 32, 128)  0           ['max_pooling2d_9[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 32, 32, 256)  295168      ['dropout_17[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_41[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 16, 16, 256)  0          ['activation_41[0][0]']
#  )
#
#  dropout_18 (Dropout)           (None, 16, 16, 256)  0           ['max_pooling2d_10[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 16, 16, 512)  1180160     ['dropout_18[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_42[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 16, 16, 512)  2359808     ['activation_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_43[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 8, 8, 512)   0           ['activation_43[0][0]']
#  )
#
#  dropout_19 (Dropout)           (None, 8, 8, 512)    0           ['max_pooling2d_11[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 8, 8, 1024)   4719616     ['dropout_19[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 8, 8, 1024)  4096        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 8, 8, 1024)   0           ['batch_normalization_44[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 8, 8, 1024)   9438208     ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 8, 8, 1024)  4096        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 8, 8, 1024)   0           ['batch_normalization_45[0][0]']
#
#  conv2d_transpose_8 (Conv2DTran  (None, 16, 16, 512)  4719104    ['activation_45[0][0]']
#  spose)
#
#  concatenate_8 (Concatenate)    (None, 16, 16, 1024  0           ['conv2d_transpose_8[0][0]',
#                                 )                                 'activation_43[0][0]']
#
#  dropout_20 (Dropout)           (None, 16, 16, 1024  0           ['concatenate_8[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 16, 16, 512)  4719104     ['dropout_20[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 16, 16, 512)  2359808     ['activation_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_47[0][0]']
#
#  conv2d_transpose_9 (Conv2DTran  (None, 32, 32, 256)  1179904    ['activation_47[0][0]']
#  spose)
#
#  concatenate_9 (Concatenate)    (None, 32, 32, 512)  0           ['conv2d_transpose_9[0][0]',
#                                                                   'activation_41[0][0]']
#
#  dropout_21 (Dropout)           (None, 32, 32, 512)  0           ['concatenate_9[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 32, 32, 256)  1179904     ['dropout_21[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_48[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_49[0][0]']
#
#  conv2d_transpose_10 (Conv2DTra  (None, 64, 64, 128)  295040     ['activation_49[0][0]']
#  nspose)
#
#  concatenate_10 (Concatenate)   (None, 64, 64, 256)  0           ['conv2d_transpose_10[0][0]',
#                                                                   'activation_39[0][0]']
#
#  dropout_22 (Dropout)           (None, 64, 64, 256)  0           ['concatenate_10[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 64, 64, 128)  295040      ['dropout_22[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 64, 64, 128)  512        ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_50[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_50[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 64, 64, 128)  512        ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_51[0][0]']
#
#  conv2d_transpose_11 (Conv2DTra  (None, 128, 128, 64  73792      ['activation_51[0][0]']
#  nspose)                        )
#
#  concatenate_11 (Concatenate)   (None, 128, 128, 12  0           ['conv2d_transpose_11[0][0]',
#                                 8)                                'activation_37[0][0]']
#
#  dropout_23 (Dropout)           (None, 128, 128, 12  0           ['concatenate_11[0][0]']
#                                 8)
#
#  conv2d_54 (Conv2D)             (None, 128, 128, 64  73792       ['dropout_23[0][0]']
#                                 )
#
#  batch_normalization_52 (BatchN  (None, 128, 128, 64  256        ['conv2d_54[0][0]']
#  ormalization)                  )
#
#  activation_52 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_52[0][0]']
#                                 )
#
#  conv2d_55 (Conv2D)             (None, 128, 128, 64  36928       ['activation_52[0][0]']
#                                 )
#
#  batch_normalization_53 (BatchN  (None, 128, 128, 64  256        ['conv2d_55[0][0]']
#  ormalization)                  )
#
#  activation_53 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_53[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 128, 128, 2)  130         ['activation_53[0][0]']
#
# ==================================================================================================
# Total params: 34,535,810
# Trainable params: 34,524,034
# Non-trainable params: 11,776
# __________________________________________________________________________________________________
# Epoch 1/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5906 - accuracy: 0.7481 - dice_loss: 0.4083 - recall_1: 0.7869 - pre_1: 0.7109
# Epoch 00001: val_loss improved from inf to 14.68321, saving model to model-TV-UNet2.h5
# 12/12 [==============================] - 14s 699ms/step - loss: 0.5906 - accuracy: 0.7481 - dice_loss: 0.4083 - recall_1: 0.7869 - pre_1: 0.7109 - val_loss: 14.6832 - val_accuracy: 0.0494 - val_dice_loss: 0.9616 - val_recall_1: 0.0372 - val_pre_1: 0.0367 - lr: 0.0010
# Epoch 2/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2815 - accuracy: 0.9820 - dice_loss: 0.2346 - recall_1: 0.9766 - pre_1: 0.9755
# Epoch 00002: val_loss improved from 14.68321 to 12.59545, saving model to model-TV-UNet2.h5
# 12/12 [==============================] - 7s 623ms/step - loss: 0.2815 - accuracy: 0.9820 - dice_loss: 0.2346 - recall_1: 0.9766 - pre_1: 0.9755 - val_loss: 12.5955 - val_accuracy: 0.2712 - val_dice_loss: 0.8050 - val_recall_1: 0.2005 - val_pre_1: 0.1880 - lr: 0.0010
# Epoch 3/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2012 - accuracy: 0.9845 - dice_loss: 0.1748 - recall_1: 0.9826 - pre_1: 0.9810
# Epoch 00003: val_loss improved from 12.59545 to 9.39682, saving model to model-TV-UNet2.h5
# 12/12 [==============================] - 6s 533ms/step - loss: 0.2012 - accuracy: 0.9845 - dice_loss: 0.1748 - recall_1: 0.9826 - pre_1: 0.9810 - val_loss: 9.3968 - val_accuracy: 0.5741 - val_dice_loss: 0.7780 - val_recall_1: 0.1792 - val_pre_1: 0.2952 - lr: 0.0010
# Epoch 4/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1614 - accuracy: 0.9839 - dice_loss: 0.1413 - recall_1: 0.9846 - pre_1: 0.9809
# Epoch 00004: val_loss improved from 9.39682 to 5.49929, saving model to model-TV-UNet2.h5
# 12/12 [==============================] - 6s 540ms/step - loss: 0.1614 - accuracy: 0.9839 - dice_loss: 0.1413 - recall_1: 0.9846 - pre_1: 0.9809 - val_loss: 5.4993 - val_accuracy: 0.7228 - val_dice_loss: 0.4861 - val_recall_1: 0.4538 - val_pre_1: 0.6004 - lr: 0.0010
# Epoch 5/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1365 - accuracy: 0.9841 - dice_loss: 0.1191 - recall_1: 0.9845 - pre_1: 0.9815
# Epoch 00005: val_loss improved from 5.49929 to 2.83243, saving model to model-TV-UNet2.h5
# 12/12 [==============================] - 6s 533ms/step - loss: 0.1365 - accuracy: 0.9841 - dice_loss: 0.1191 - recall_1: 0.9845 - pre_1: 0.9815 - val_loss: 2.8324 - val_accuracy: 0.9008 - val_dice_loss: 0.2444 - val_recall_1: 0.7291 - val_pre_1: 0.8003 - lr: 0.0010
# Epoch 6/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1182 - accuracy: 0.9846 - dice_loss: 0.1026 - recall_1: 0.9851 - pre_1: 0.9821
# Epoch 00006: val_loss improved from 2.83243 to 0.41464, saving model to model-TV-UNet2.h5
# 12/12 [==============================] -
50
# 12/12 [==============================] - ETA: 0s - loss: 0.0328 - accuracy: 0.9890 - dice_loss: 0.0232 - recall_1: 0.9894 - pre_1: 0.9884
# Epoch 00041: val_loss improved from 0.03269 to 0.03249, saving model to model-TV-UNet2.h5
# 12/12 [==============================] - 7s 571ms/step - loss: 0.0328 - accuracy: 0.9890 - dice_loss: 0.0232 - recall_1: 0.9894 - pre_1: 0.9884 - val_loss: 0.0325 - val_accuracy: 0.9892 - val_dice_loss: 0.0182 - val_recall_1: 0.9922 - val_pre_1: 0.9860 - lr: 1.0000e-04
# Epoch 42/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0325 - accuracy: 0.9888 - dice_loss: 0.0220 - recall_1: 0.9894 - pre_1: 0.9883
# Epoch 00042: val_loss improved from 0.03249 to 0.03214, saving model to model-TV-UNet2.h5
# 12/12 [==============================] - 7s 576ms/step - loss: 0.0325 - accuracy: 0.9888 - dice_loss: 0.0220 - recall_1: 0.9894 - pre_1: 0.9883 - val_loss: 0.0321 - val_accuracy: 0.9893 - val_dice_loss: 0.0180 - val_recall_1: 0.9922 - val_pre_1: 0.9859 - lr: 1.0000e-04
# Epoch 43/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0315 - accuracy: 0.9895 - dice_loss: 0.0217 - recall_1: 0.9897 - pre_1: 0.9890
# Epoch 00043: val_loss improved from 0.03214 to 0.03157, saving model to model-TV-UNet2.h5
# 12/12 [==============================] - 7s 625ms/step - loss: 0.0315 - accuracy: 0.9895 - dice_loss: 0.0217 - recall_1: 0.9897 - pre_1: 0.9890 - val_loss: 0.0316 - val_accuracy: 0.9889 - val_dice_loss: 0.0182 - val_recall_1: 0.9917 - val_pre_1: 0.9871 - lr: 1.0000e-04
# Epoch 44/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0315 - accuracy: 0.9893 - dice_loss: 0.0217 - recall_1: 0.9894 - pre_1: 0.9893
# Epoch 00044: val_loss improved from 0.03157 to 0.03142, saving model to model-TV-UNet2.h5
# 12/12 [==============================] - 7s 572ms/step - loss: 0.0315 - accuracy: 0.9893 - dice_loss: 0.0217 - recall_1: 0.9894 - pre_1: 0.9893 - val_loss: 0.0314 - val_accuracy: 0.9892 - val_dice_loss: 0.0183 - val_recall_1: 0.9918 - val_pre_1: 0.9870 - lr: 1.0000e-04
# Epoch 45/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0314 - accuracy: 0.9893 - dice_loss: 0.0215 - recall_1: 0.9894 - pre_1: 0.9891
# Epoch 00045: val_loss did not improve from 0.03142
# 12/12 [==============================] - 6s 523ms/step - loss: 0.0314 - accuracy: 0.9893 - dice_loss: 0.0215 - recall_1: 0.9894 - pre_1: 0.9891 - val_loss: 0.0319 - val_accuracy: 0.9895 - val_dice_loss: 0.0178 - val_recall_1: 0.9921 - val_pre_1: 0.9865 - lr: 1.0000e-04
# Epoch 46/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0312 - accuracy: 0.9893 - dice_loss: 0.0213 - recall_1: 0.9897 - pre_1: 0.9890
# Epoch 00046: val_loss did not improve from 0.03142
# 12/12 [==============================] - 6s 523ms/step - loss: 0.0312 - accuracy: 0.9893 - dice_loss: 0.0213 - recall_1: 0.9897 - pre_1: 0.9890 - val_loss: 0.0325 - val_accuracy: 0.9894 - val_dice_loss: 0.0179 - val_recall_1: 0.9920 - val_pre_1: 0.9862 - lr: 1.0000e-04
# Epoch 47/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0313 - accuracy: 0.9892 - dice_loss: 0.0211 - recall_1: 0.9900 - pre_1: 0.9886
# Epoch 00047: val_loss did not improve from 0.03142
# 12/12 [==============================] - 6s 521ms/step - loss: 0.0313 - accuracy: 0.9892 - dice_loss: 0.0211 - recall_1: 0.9900 - pre_1: 0.9886 - val_loss: 0.0322 - val_accuracy: 0.9892 - val_dice_loss: 0.0176 - val_recall_1: 0.9921 - val_pre_1: 0.9862 - lr: 1.0000e-04
# Epoch 48/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9894 - dice_loss: 0.0211 - recall_1: 0.9902 - pre_1: 0.9888
# Epoch 00048: val_loss did not improve from 0.03142
# 12/12 [==============================] - 6s 526ms/step - loss: 0.0309 - accuracy: 0.9894 - dice_loss: 0.0211 - recall_1: 0.9902 - pre_1: 0.9888 - val_loss: 0.0322 - val_accuracy: 0.9894 - val_dice_loss: 0.0176 - val_recall_1: 0.9920 - val_pre_1: 0.9864 - lr: 1.0000e-04
# Epoch 49/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0308 - accuracy: 0.9894 - dice_loss: 0.0211 - recall_1: 0.9900 - pre_1: 0.9890
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00049: val_loss did not improve from 0.03142
# 12/12 [==============================] - 6s 521ms/step - loss: 0.0308 - accuracy: 0.9894 - dice_loss: 0.0211 - recall_1: 0.9900 - pre_1: 0.9890 - val_loss: 0.0322 - val_accuracy: 0.9896 - val_dice_loss: 0.0175 - val_recall_1: 0.9922 - val_pre_1: 0.9862 - lr: 1.0000e-04
# Epoch 50/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0305 - accuracy: 0.9895 - dice_loss: 0.0208 - recall_1: 0.9902 - pre_1: 0.9890
# Epoch 00050: val_loss did not improve from 0.03142
# 12/12 [==============================] - 6s 522ms/step - loss: 0.0305 - accuracy: 0.9895 - dice_loss: 0.0208 - recall_1: 0.9902 - pre_1: 0.9890 - val_loss: 0.0320 - val_accuracy: 0.9895 - val_dice_loss: 0.0174 - val_recall_1: 0.9921 - val_pre_1: 0.9863 - lr: 1.0000e-05
# 100%|██████████| 3/3 [00:22<00:00,  7.44s/it]
# 17/17 [==============================] - 3s 158ms/step
# 17/17 [==============================] - 3s 156ms/step
# '#########################################################################'

# %%
'''#########################################################################'''
########## plot Pre_Recall curve
from sklearn.metrics import precision_recall_curve

from sklearn.metrics import average_precision_score

labels = []

########## For Unet Model
precision1 = dict()
recall1 = dict()
average_precision1 = dict()

for i in range(num_class):
  y_test_f=K.flatten(label_test[:,:,:,i])
  preds_test_f=K.flatten(preds_test1[:,:,:,i])
  precision1[i], recall1[i], _ = precision_recall_curve(y_test_f,preds_test_f)
                                                       
  average_precision1[i] = average_precision_score(y_test_f,preds_test_f)
  
##################################################
# A "micro-average": quantifying score on all classes jointly
y_test_f=K.flatten(label_test[:,:,:,1])
preds_test_f=K.flatten(preds_test1[:,:,:,1])
precision1["micro"], recall1["micro"], _ = precision_recall_curve(y_test_f,preds_test_f)
average_precision1["micro"] = average_precision_score(y_test_f,preds_test_f,
                                                     average="micro")

########## For TV_Unet Model
precision2 = dict()
recall2 = dict()
average_precision2 = dict()

for i in range(num_class):
  y_test_f=K.flatten(label_test[:,:,:,i])
  preds_test_f=K.flatten(preds_test2[:,:,:,i])
  precision2[i], recall2[i], _ = precision_recall_curve(y_test_f,preds_test_f)
                                                       
  average_precision2[i] = average_precision_score(y_test_f,preds_test_f)
  
##################################################
# A "micro-average": quantifying score on all classes jointly
y_test_f=K.flatten(label_test[:,:,:,1])
preds_test_f=K.flatten(preds_test2[:,:,:,1])
precision2["micro"], recall2["micro"], _ = precision_recall_curve(y_test_f,preds_test_f)
average_precision2["micro"] = average_precision_score(y_test_f,preds_test_f,
                                                     average="micro")

##################################################


plt.figure(figsize=(7, 8))
plt.step(recall1['micro'], precision1['micro'], where='post', color='b', 
         label='Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']))

plt.step(recall2['micro'], precision2['micro'], where='post', color='r',
         label='Average-Precision for TV-Unet Model ({0:0.2f})'.format(average_precision2['micro']))


plt.xlabel('Recall', size=13)
plt.ylabel('Precision', size=13)
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])

plt.title('Extension of Precision-Recall curve')
plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
           'Average-Precision for TV-Unet Model ({0:0.2f})'.format(average_precision2['micro']))

'''#########################################################################'''
########## calculate precision and recall for each Model
tre=np.arange(0.1,1,0.1).tolist()

y_test_f=K.flatten(label_test[:,:,:,1])
preds_test_f=K.flatten(preds_test1[:,:,:,1])
m = tf.keras.metrics.Recall(thresholds=tre)
n = tf.keras.metrics.Precision(thresholds=tre)
m.update_state(y_test_f, preds_test_f)
n.update_state(y_test_f, preds_test_f)
recal_unet=m.result().numpy()
pre_unet=n.result().numpy()
print('recall_unet=',recal_unet)
print('precision_unet=',pre_unet)

m.reset_states()
n.reset_states()
y_test_f=K.flatten(y_train[:,:,:,1])
preds_test_f=K.flatten(preds_test2[:,:,:,1])
m = tf.keras.metrics.Recall(thresholds=tre)
n = tf.keras.metrics.Precision(thresholds=tre)
m.update_state(y_test_f, preds_test_f)
n.update_state(y_test_f, preds_test_f)
recal_TVUnet=m.result().numpy()
pre_TVUnet=n.result().numpy()
print('recall_TV Unet=',recal_TVUnet)
print('precision_TV Unet=',pre_TVUnet)

'''#########################################################################'''
########## calculate dice score for each model
def dice_coef(y_pred, y_true):
  for tr in np.arange(0.1,1,0.1):
    y_pred_t = (y_pred[:,:,:,1] > tr).astype(np.uint8)
    y_true_f = np.array(y_true[:,:,:,1])
    y_pred_f = np.array(y_pred_t)
    intersection = np.sum(y_true_f * y_pred_f)
    print( 2*(intersection) / (np.sum(y_true_f) + np.sum(y_pred_f)))

dice=dice_coef(preds_test1,label_test)
print('Unet DSC=', dice)

dice=dice_coef(preds_test2,label_test)
print('TV Unet DSC=', dice)

'''#########################################################################'''
########## calculate mIOU
def jaccard_distance_loss(y_true, y_pred, smooth=100):
  for tr in np.arange(0.1,1,0.1):
    """
    Jaccard = (|X & Y|)/ (|X|+ |Y| - |X & Y|)
            = sum(|A*B|)/(sum(|A|)+sum(|B|)-sum(|A*B|))
    """
    y_pred_t = (y_pred[:,:,:,:] > tr).astype(np.uint8)
    y_true_f = np.array(y_true[:,:,:,:])
    y_pred_f = np.array(y_pred_t)
    intersection = np.sum(y_true_f * y_pred_f,axis=-1)
    sum_ = np.sum(np.abs(y_true_f) + np.abs(y_pred_f),axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    print(np.mean(jac))

mIOU=jaccard_distance_loss(label_test, preds_test1)
print('Unet mIOU=', mIOU)

mIOU=jaccard_distance_loss(label_test, preds_test2)
print('Unet mIOU=', mIOU)
# Out:
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support 'A' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support 'v' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support 'e' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support 'r' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support 'a' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support 'g' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support '-' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support 'P' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support 'c' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support 'i' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support 's' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support 'o' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support 'n' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support ' ' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support 'f' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support 'U' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support 't' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support 'M' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support 'd' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support 'l' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support '(' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support '0' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support '.' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support '6' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support '2' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py:66: UserWarning: Legend does not support ')' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend('Average-Precision for Unet Model ({0:0.2f})'.format(average_precision1['micro']),
# recall_unet= [0.83344024 0.7437707  0.6738317  0.6096674  0.5467864  0.47064486
#  0.3727409  0.21880013 0.0165223 ]
# precision_unet= [0.4210768  0.5023656  0.5525981  0.59382325 0.63772994 0.68738776
#  0.74025697 0.78136337 0.9307229 ]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /data/jwd/main/040/914/40914875/tmp/ipykernel_1095/956160351.py in <module>
#      88 m = tf.keras.metrics.Recall(thresholds=tre)
#      89 n = tf.keras.metrics.Precision(thresholds=tre)
# ---> 90 m.update_state(y_test_f, preds_test_f)
#      91 n.update_state(y_test_f, preds_test_f)
#      92 recal_TVUnet=m.result().numpy()
#
# /opt/conda/lib/python3.9/site-packages/keras/utils/metrics_utils.py in decorated(metric_obj, *args, **kwargs)
#      71
#      72     with tf_utils.graph_context_for_symbolic_tensors(*args, **kwargs):
# ---> 73       update_op = update_state_fn(*args, **kwargs)
#      74     if update_op is not None:  # update_op will be None in eager execution.
#      75       metric_obj.add_update(update_op)
#
# /opt/conda/lib/python3.9/site-packages/keras/metrics.py in update_state_fn(*args, **kwargs)
#     175         control_status = tf.__internal__.autograph.control_status_ctx()
#     176         ag_update_state = tf.__internal__.autograph.tf_convert(obj_update_state, control_status)
# --> 177         return ag_update_state(*args, **kwargs)
#     178     else:
#     179       if isinstance(obj.update_state, tf.__internal__.function.Function):
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     694       try:
#     695         with conversion_ctx:
# --> 696           return converted_call(f, args, kwargs, options=options)
#     697       except Exception as e:  # pylint:disable=broad-except
#     698         if hasattr(e, 'ag_error_metadata'):
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     335   if conversion.is_in_allowlist_cache(f, options):
#     336     logging.log(2, 'Allowlisted %s: from cache', f)
# --> 337     return _call_unconverted(f, args, kwargs, options, False)
#     338
#     339   if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     462
#     463   if kwargs is not None:
# --> 464     return f(*args, **kwargs)
#     465   return f(*args)
#     466
#
# /opt/conda/lib/python3.9/site-packages/keras/metrics.py in update_state(self, y_true, y_pred, sample_weight)
#    1527       Update op.
#    1528     """
# -> 1529     return metrics_utils.update_confusion_matrix_variables(
#    1530         {
#    1531             metrics_utils.ConfusionMatrix.TRUE_POSITIVES: self.true_positives,
#
# /opt/conda/lib/python3.9/site-packages/keras/utils/metrics_utils.py in update_confusion_matrix_variables(variables_to_update, y_true, y_pred, thresholds, top_k, class_id, sample_weight, multi_label, label_weights, thresholds_distributed_evenly)
#     623           losses_utils.squeeze_or_expand_dimensions(
#     624               y_pred, y_true, sample_weight=sample_weight))
# --> 625   y_pred.shape.assert_is_compatible_with(y_true.shape)
#     626
#     627   if top_k is not None:
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/tensor_shape.py in assert_is_compatible_with(self, other)
#    1169     """
#    1170     if not self.is_compatible_with(other):
# -> 1171       raise ValueError("Shapes %s and %s are incompatible" % (self, other))
#    1172
#    1173   def most_specific_compatible_shape(self, other):
#
# ValueError: Shapes (8683520,) and (5898240,) are incompatible
